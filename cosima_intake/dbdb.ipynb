# %% [markdown]
# # A database of databases
#
# Exploring the functionality of an intake catalogue of intake-esm catalogues using COSIMA data as a test case.
#
# Concept:
#
# One intake-esm catalogue per "experiment" and another catalogue for finding relevant experiments.
#
# Useful links:
#
# - https://github.com/pangeo-data/pangeo-datastore

# %%
import os

import pathlib

import intake

import xarray as xr

# %%
# %cd /g/data/tm70/ds0092/projects/dev_data_querying/cosima_intake
# Out:
# /g/data/tm70/ds0092/projects/dev_data_querying/cosima_intake

# %%
index_directories = [
    "/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1",
    "/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle2",
    "/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle3"
]

# %% [markdown]
# ## Build intake-esm catalogues

# %%
from ecgtools import Builder

from ecgtools_parsers import cosima_parser

# %%
index_directory = index_directories[0]

# %%
test_directory = "/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000"

# %%
b = Builder(
    [test_directory],
    depth=2,
    # exclude_patterns=["*/restart*/*", "*/RESTART*/*"],
    include_patterns=["*.nc"],
    joblib_parallel_kwargs={"n_jobs": 4},
    )

# %%
b.get_assets()
# Out:
# Builder(paths=['/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000'], storage_options={}, depth=2, exclude_patterns=[], include_patterns=['*.nc'], joblib_parallel_kwargs={'n_jobs': 4})

# %%
b.parse(
# Out:
# ['/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-01-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-01.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-02-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-02.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-03-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-03.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-04-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-04.nc',
# ...

# %%
b = b.build(parsing_func=cosima_parser)
# Out:
# exception calling callback for <Future at 0x148cedb7f0a0 state=finished raised BrokenProcessPool>
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/g/data/tm70/ds0092/software/mambaforge/envs/cosima-intake/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py", line 391, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/g/data/tm70/ds0092/software/mambaforge/envs/cosima-intake/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'ecgtools_parsers'
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/tm70/ds0092/software/mambaforge/envs/cosima-intake/lib/python3.10/site-packages/joblib/externals/loky/_base.py", line 26, in _invoke_callbacks
#     callback(self)
# ...

# %%
b.assets
# Out:
# ['/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-01-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-01.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-02-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-02.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-03-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-03.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-04-daily.nc',
#  '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/output000/ice/OUTPUT/iceh.1958-04.nc',
# ...

# %%
# %%time

for index_directory in index_directories[:1]:
    cc_builder = Builder(
        [index_directory],
        depth=1,
        exclude_patterns=["*/restart*/*"], # Exclude restart directories
    )

    cc_builder = cc_builder.build(parsing_func=parse_cc)

    # cc_builder.save(
    #     f"{os.path.basename(index_directory)}.csv",
    #     path_column_name='path',
    #     variable_column_name='variables',
    #     data_format="netcdf",
    #     # Which attributes to groupby when reading in variables using intake-esm
    #     groupby_attrs=["experiment", "filename"],
    #     aggregations=[
    #         {
    #             "type": "join_existing",
    #             "attribute_name": "start_time",
    #             "options": {"dim": "time", "combine": "by_coords"},
    #         }
    #     ],
    # )
# Out:
# CPU times: user 483 ms, sys: 1.35 s, total: 1.84 s
# Wall time: 8.65 s

# %%
cc_builder.entries
# Out:
# [{'INVALID_ASSET': '/g/data/ik11/outputs/access-om2-025/025deg_jra55_iaf_omip2_cycle1/error_logs/access-om2.13167265.gadi-pbs.err',
# ...
